# %%
import numpy as np
import pandas as pd

# %%
books=pd.read_csv("Books.csv")
ratings=pd.read_csv("Ratings.csv")
users=pd.read_csv("Users.csv")
# Out:
# C:\Users\ruhan\AppData\Local\Temp\ipykernel_15764\2055901106.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv("Books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.shape
# Out:
# (271360, 8)

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
users.shape
# Out:
# (278858, 3)

# %% [markdown]
# #EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

most_read = books['Book-Title'].value_counts().head(30).reset_index()
most_read.columns = ['bookTitle', 'count']

plt.figure(figsize=(5, 5))
plt.title("Most Read Books")
sns.barplot(x='count', y='bookTitle', data=most_read)
plt.show()

# %%
merged_data = pd.merge(books, ratings, on='ISBN')
merged_data =  merged_data.sort_values('ISBN', ascending=True)
merged_data.head()
# Out:
#                ISBN                                         Book-Title  \
# 1013651  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968138   0001010565                                    Mog's Christmas
# 968139   0001010565                                    Mog's Christmas
# 542150   0001046438                                               Liar
# 788100   0001046713                       Twopence to Cross the Mersey
#
#                            Book-Author Year-Of-Publication  \
# 1013651  C. van Amerongen (translator)                1967
# 968138                     Judith Kerr                1992
# 968139                     Judith Kerr                1992
# 542150                     Stephen Fry                   0
# 788100                 Helen Forrester                1992
#
#                         Publisher  \
# 1013651      Simon &amp; Schuster
# 968138                    Collins
# 968139                    Collins
# 542150           Harpercollins Uk
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

top_rated = merged_data[['Book-Title', 'Book-Rating']]
top_rated = top_rated.groupby('Book-Title', as_index=False)['Book-Rating'].mean()
top_rated = top_rated.sort_values('Book-Rating', ascending=False).reset_index()
top_rated = top_rated[['Book-Title', 'Book-Rating']]

plt.figure(figsize=(5, 5))
plt.title("Most rated Books")
sns.barplot(x='Book-Rating', y='Book-Title', data=top_rated.head(30))
plt.show()

# %%
most_read_Book_Author = merged_data['Book-Author'].value_counts().head(30).reset_index()
most_read_Book_Author.columns = ['bookAuthor', 'count']

plt.figure(figsize=(5, 5))
plt.title("Most Read Book-Author")
sns.barplot(x='count', y='bookAuthor', data=most_read_Book_Author)
plt.show()

# %%
most_Year_Of_Publication = merged_data['Year-Of-Publication'].value_counts().head(30).reset_index()
most_Year_Of_Publication.columns = ['Year-Of-Publication', 'count']

plt.figure(figsize=(5, 5))
plt.title("Most Year-Of-Publication of books")
sns.barplot(x='count', y='Year-Of-Publication', data=most_Year_Of_Publication)
plt.show()

# %% [markdown]
# # POPULARITY BASED POPULARITY SYSTEM

# %%
merged_data.head()
# Out:
#                ISBN                                         Book-Title  \
# 1013651  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968138   0001010565                                    Mog's Christmas
# 968139   0001010565                                    Mog's Christmas
# 542150   0001046438                                               Liar
# 788100   0001046713                       Twopence to Cross the Mersey
#
#                            Book-Author Year-Of-Publication  \
# 1013651  C. van Amerongen (translator)                1967
# 968138                     Judith Kerr                1992
# 968139                     Judith Kerr                1992
# 542150                     Stephen Fry                   0
# 788100                 Helen Forrester                1992
#
#                         Publisher  \
# 1013651      Simon &amp; Schuster
# 968138                    Collins
# 968139                    Collins
# 542150           Harpercollins Uk
# ...

# %%
num_rating_df = merged_data.groupby("Book-Title").count()["Book-Rating"].reset_index()
num_rating_df.rename(columns={"Book-Rating":"Num-Rating"},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  Num-Rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = merged_data.groupby("Book-Title").mean()["Book-Rating"].reset_index()
avg_rating_df.rename(columns={"Book-Rating":"avg-Rating"},inplace=True)
avg_rating_df
# Out:
# C:\Users\ruhan\AppData\Local\Temp\ipykernel_15764\1558119200.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = merged_data.groupby("Book-Title").mean()["Book-Rating"].reset_index()
#                                                Book-Title  avg-Rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# ...

# %%
popular_df=num_rating_df.merge(avg_rating_df,on="Book-Title")
popular_df
# Out:
#                                                Book-Title  Num-Rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         avg-Rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# 4         0.000000
# ...

# %%
popular_df=popular_df[popular_df["Num-Rating"]>250].sort_values("avg-Rating",ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  Num-Rating  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 80422        Harry Potter and the Goblet of Fire (Book 4)         387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)         278
# 80426   Harry Potter and the Order of the Phoenix (Boo...         347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)         556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...         575
# 211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 219741                              To Kill a Mockingbird         510
# 183573                                  The Da Vinci Code         898
# 187880                 The Five People You Meet in Heaven         430
# ...

# %% [markdown]
# # COLABORATIVE FILTERING

# %%
merged_data
# Out:
#                ISBN                                         Book-Title  \
# 1013651  0000913154  The Way Things Work: An Illustrated Encycloped...
# 968138   0001010565                                    Mog's Christmas
# 968139   0001010565                                    Mog's Christmas
# 542150   0001046438                                               Liar
# 788100   0001046713                       Twopence to Cross the Mersey
# ...             ...                                                ...
# 670608   B000234N76                                     Falling Angels
# 937591   B000234NC6  It Must've Been Something I Ate: The Return of...
# 828933   B00029DGGO                        Good Wife Strikes Back, The
# 916406   B0002JV9PY                               The Blockade Runners
# 916404   B0002K6K8O                               The Underground City
#
#                            Book-Author Year-Of-Publication  \
# ...

# %%
x = merged_data.groupby("User-ID").count()['Book-Rating'] > 200
good_user = x[x].index

# %%
filtered_ratings = merged_data[merged_data['User-ID'].isin(good_user)]

# %%
y = filtered_ratings.groupby("Book-Title").count()['Book-Rating'] > 50
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=679)

# %%
final_ratings = filtered_ratings[filtered_ratings['Book-Title'].isin(famous_books)]

# %%
final_ratings.head()
# Out:
#               ISBN                                         Book-Title  \
# 307405  0001047973                                    Brave New World
# 921794  0006177379                                            Secrets
# 996321  0020697406                                     The Lost World
# 139443  002542730X  Politically Correct Bedtime Stories: Modern Ta...
# 139388  002542730X  Politically Correct Bedtime Stories: Modern Ta...
#
#               Book-Author Year-Of-Publication                    Publisher  \
# 307405      Aldous Huxley                1999  Trafalgar Square Publishing
# 921794         Vera Cowie                1990     HarperCollins Publishers
# 996321    Randall Jarrell                1985         Simon &amp; Schuster
# 139443  James Finn Garner                1994    John Wiley &amp; Sons Inc
# 139388  James Finn Garner                1994    John Wiley &amp; Sons Inc
#
#                                               Image-URL-S  \
# ...

# %%
pt = final_ratings.pivot_table(index="Book-Title",columns="User-ID",values="Book-Rating")

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score.shape
# Out:
# (679, 679)

# %%
def recommend(book_name):
    #fetch index of the book
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])),key = lambda x: x[1],reverse=True)[1:6]
    for i in similar_items:
        print(pt.index[i[0]])

# %%
recommend("Message in a Bottle")
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes
